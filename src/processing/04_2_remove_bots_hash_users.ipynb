# %% [markdown]
# ### 1. Extract all contributors

# %%
import pandas as pd

proj_hack_member = pd.read_csv('../data/hackathon_project_contributor.csv')

proj_hack_member

# %%
all_links = proj_hack_member['contributors'].dropna().str.split(',')

flat_links = [link.strip() for sublist in all_links for link in sublist]

unique_links = list(set(flat_links))

contributors_df = pd.DataFrame({
    'link': unique_links,
    'name': [link.split('/')[-1] for link in unique_links]
})

contributors_df.to_csv('contributors.csv', index=False)

# %% [markdown]
# ### 2. Run RABBIT to identify GitHub users as Bot/Human/Unknown (in run_rabbit_parallel.py)

# %% [markdown]
# ### 3. Process to keep Human users (or Human and Unknown users?)
#
# Human: 34258
# Human and Unknown: 174173

# %%
import pandas as pd

rabbit_res = pd.read_csv('../data/rabbit_output_parallel.csv')

rabbit_res
# Out:
#         Unnamed: 0      contributor     type confidence
# 0                0            kylaf  Unknown          -
# 1                1    sophiapeckner  Unknown          -
# 2                2    LaExploradora  Unknown          -
# 3                3     ashlaycyriac  Unknown          -
# 4                4          Erlemar      Bot      0.757
# ...            ...              ...      ...        ...
# 195039       32499       ajaysub110      Bot      0.213
# 195040       32500       bodokaiser    Human      0.801
# 195041       32501           Omig12  Unknown          -
# 195042       32502  craig-ludington  Unknown          -
# 195043       32503         jbskytap  Unknown          -
#
# [195044 rows x 4 columns]

# %% [markdown]
# Confidence of users marked as Human

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# sns.histplot(data=rabbit_res[rabbit_res["type"] == "Human"], x="confidence", bins=30)
# plt.title("Confidence distribution for type=human")
# plt.show()

rabbit_res["confidence"] = pd.to_numeric(rabbit_res["confidence"], errors="coerce")
human_conf = rabbit_res[(rabbit_res["type"] == "Human") & (rabbit_res["confidence"].notna())]["confidence"]

bins = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
binned = pd.cut(human_conf, bins=bins)

print(binned.value_counts().sort_index())
print("\nPercent distribution:")
print((binned.value_counts(normalize=True) * 100).sort_index().round(2).astype(str) + "%")
# Out:
# confidence
# (0.5, 0.6]     1840
# (0.6, 0.7]     2449
# (0.7, 0.8]     3493
# (0.8, 0.9]     7521
# (0.9, 1.0]    12662
# Name: count, dtype: int64
#
# Percent distribution:
# confidence
# (0.5, 0.6]     6.58%
# (0.6, 0.7]     8.76%
# (0.7, 0.8]    12.49%
# (0.8, 0.9]    26.89%
# (0.9, 1.0]    45.28%
# Name: proportion, dtype: object

# %%
is_human = rabbit_res[rabbit_res['type'] == 'Human']

is_human
# Out:
#         Unnamed: 0     contributor   type confidence
# 5                5         ncitron  Human      0.956
# 13              13       devantler  Human      0.819
# 15              15  roseeichelmann  Human      0.834
# 21              21  Aishwaryajakka  Human      0.793
# 22              22     marcosgopen  Human      0.936
# ...            ...             ...    ...        ...
# 195031       32491        jackcook  Human       0.85
# 195032       32492       ottomated  Human      0.813
# 195034       32494        adriangb  Human      0.937
# 195035       32495         wanglam  Human      0.921
# 195040       32500      bodokaiser  Human      0.801
#
# [34258 rows x 4 columns]

# %%
not_bot = rabbit_res[rabbit_res['type'].isin(['Human', 'Unknown'])]

not_bot
# Out:
#         Unnamed: 0      contributor     type confidence
# 0                0            kylaf  Unknown          -
# 1                1    sophiapeckner  Unknown          -
# 2                2    LaExploradora  Unknown          -
# 3                3     ashlaycyriac  Unknown          -
# 5                5          ncitron    Human      0.956
# ...            ...              ...      ...        ...
# 195038       32498      mastrolinux  Unknown          -
# 195040       32500       bodokaiser    Human      0.801
# 195041       32501           Omig12  Unknown          -
# 195042       32502  craig-ludington  Unknown          -
# 195043       32503         jbskytap  Unknown          -
#
# [174173 rows x 4 columns]

# %%
contributors_df = pd.read_csv('../contributors.csv')
contributors_df
# Out:
#                                       link             name
# 0                 https://github.com/kylaf            kylaf
# 1         https://github.com/sophiapeckner    sophiapeckner
# 2         https://github.com/LaExploradora    LaExploradora
# 3          https://github.com/ashlaycyriac     ashlaycyriac
# 4               https://github.com/Erlemar          Erlemar
# ...                                    ...              ...
# 195039       https://github.com/ajaysub110       ajaysub110
# 195040       https://github.com/bodokaiser       bodokaiser
# 195041           https://github.com/Omig12           Omig12
# 195042  https://github.com/craig-ludington  craig-ludington
# 195043         https://github.com/jbskytap         jbskytap
#
# [195044 rows x 2 columns]

# %%
humans = pd.merge(
    is_human, contributors_df,
    how='left',
    left_on='contributor', right_on='name',
)
humans = humans[['link','name']]
humans
# Out:
#                                     link            name
# 0             https://github.com/ncitron         ncitron
# 1           https://github.com/devantler       devantler
# 2      https://github.com/roseeichelmann  roseeichelmann
# 3      https://github.com/Aishwaryajakka  Aishwaryajakka
# 4         https://github.com/marcosgopen     marcosgopen
# ...                                  ...             ...
# 34253        https://github.com/jackcook        jackcook
# 34254       https://github.com/ottomated       ottomated
# 34255        https://github.com/adriangb        adriangb
# 34256         https://github.com/wanglam         wanglam
# 34257      https://github.com/bodokaiser      bodokaiser
#
# [34258 rows x 2 columns]

# %%
human_and_unknown = pd.merge(
    not_bot, contributors_df,
    how='left',
    left_on='contributor', right_on='name',
)
human_and_unknown = human_and_unknown[['link','name']]
human_and_unknown
# Out:
#                                       link             name
# 0                 https://github.com/kylaf            kylaf
# 1         https://github.com/sophiapeckner    sophiapeckner
# 2         https://github.com/LaExploradora    LaExploradora
# 3          https://github.com/ashlaycyriac     ashlaycyriac
# 4               https://github.com/ncitron          ncitron
# ...                                    ...              ...
# 174168      https://github.com/mastrolinux      mastrolinux
# 174169       https://github.com/bodokaiser       bodokaiser
# 174170           https://github.com/Omig12           Omig12
# 174171  https://github.com/craig-ludington  craig-ludington
# 174172         https://github.com/jbskytap         jbskytap
#
# [174173 rows x 2 columns]

# %% [markdown]
# Filter out bots by name: if it contains the word 'bot', remove it

# %%
humans = humans[
    ~(
        humans['link'].str.contains('bot', case=False, na=False) |
        humans['name'].str.contains('bot', case=False, na=False)
    )
]
humans
# Out:
#                                     link            name
# 0             https://github.com/ncitron         ncitron
# 1           https://github.com/devantler       devantler
# 2      https://github.com/roseeichelmann  roseeichelmann
# 3      https://github.com/Aishwaryajakka  Aishwaryajakka
# 4         https://github.com/marcosgopen     marcosgopen
# ...                                  ...             ...
# 34253        https://github.com/jackcook        jackcook
# 34254       https://github.com/ottomated       ottomated
# 34255        https://github.com/adriangb        adriangb
# 34256         https://github.com/wanglam         wanglam
# 34257      https://github.com/bodokaiser      bodokaiser
#
# [34180 rows x 2 columns]

# %%
human_and_unknown = human_and_unknown[
    ~(
        human_and_unknown['link'].str.contains('bot', case=False, na=False) |
        human_and_unknown['name'].str.contains('bot', case=False, na=False)
    )
]
human_and_unknown
# Out:
#                                       link             name
# 0                 https://github.com/kylaf            kylaf
# 1         https://github.com/sophiapeckner    sophiapeckner
# 2         https://github.com/LaExploradora    LaExploradora
# 3          https://github.com/ashlaycyriac     ashlaycyriac
# 4               https://github.com/ncitron          ncitron
# ...                                    ...              ...
# 174168      https://github.com/mastrolinux      mastrolinux
# 174169       https://github.com/bodokaiser       bodokaiser
# 174170           https://github.com/Omig12           Omig12
# 174171  https://github.com/craig-ludington  craig-ludington
# 174172         https://github.com/jbskytap         jbskytap
#
# [173783 rows x 2 columns]

# %% [markdown]
# ### 4. Hash users with SHA256

# %% [markdown]
# Only human:

# %%
import hashlib

def hash_link(link):
    return hashlib.sha256(link.encode('utf-8')).hexdigest()

humans['hash'] = humans['link'].apply(hash_link)

humans.to_csv('../data/humans_hash.csv', index=False)
# Out:
# C:\Windows\Temp\ipykernel_4344\90664648.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   humans['hash'] = humans['link'].apply(hash_link)

# %% [markdown]
# Human and unknown:

# %%
import hashlib

def hash_link(link):
    return hashlib.sha256(link.encode('utf-8')).hexdigest()

human_and_unknown['hash'] = human_and_unknown['link'].apply(hash_link)

human_and_unknown.to_csv('../data/humans_hash_complete.csv', index=False)
# Out:
# C:\Windows\Temp\ipykernel_4344\3856434441.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_and_unknown['hash'] = human_and_unknown['link'].apply(hash_link)

# %% [markdown]
# ### 5. Only keep Human in hackathon_project_contributor.csv

# %% [markdown]
# ##### 5.1 Only keep human

# %%
proj_hack_member = pd.read_csv('../data/hackathon_project_contributor.csv')
humans_hash = pd.read_csv('../data/humans_hash.csv')

valid_links = set(humans_hash['link'])

# only keep links of human users
def filter_contributors(contributor_str):
    if pd.isna(contributor_str):
        return []
    links = [link.strip() for link in contributor_str.split(',')]
    filtered = [link for link in links if link in valid_links]
    return filtered

proj_hack_member['contributors'] = proj_hack_member['contributors'].apply(filter_contributors)

# Only keep the projects with more than 1 human contributors
proj_hack_member = proj_hack_member[proj_hack_member['contributors'].apply(len) > 1]

# Transfer the contributor list back to string
proj_hack_member['contributors'] = proj_hack_member['contributors'].apply(lambda lst: ','.join(lst))

link_to_name = dict(zip(humans_hash['link'], humans_hash['name']))

def map_links_to_names(contributor_str):
    links = contributor_str.split(',')
    names = [link_to_name.get(link.strip()) for link in links if link.strip() in link_to_name]
    return ','.join(names)

proj_hack_member['contributor_github_username'] = proj_hack_member['contributors'].apply(map_links_to_names)

proj_hack_member.to_csv('../data/proj_hack_human.csv',index=False)
proj_hack_member
# Out:
#                                            hackathon_URL  \
# 5                         https://supernova.devpost.com/
# 8                         https://supernova.devpost.com/
# 18                        https://supernova.devpost.com/
# 21                        https://supernova.devpost.com/
# 42                        https://supernova.devpost.com/
# ...                                                  ...
# 76016        https://level-up-society-13094.devpost.com/
# 76017   https://realityfest-exhibition-hall.devpost.com/
# 76081            https://cosmos-hackatom-vi.devpost.com/
# 76082                   https://hackatom-ru.devpost.com/
# 76104  https://azure-sentinel-hackathon-2021.devpost....
#
#                                              project_URL  \
# 5      https://devpost.com/software/meta-yield-liquid...
# 8           https://devpost.com/software/nnsdao-protocol
# 18                    https://devpost.com/software/candb
# 21                     https://devpost.com/software/mops
# 42                   https://devpost.com/software/deadly
# ...                                                  ...
# 76016        https://devpost.com/software/saviour-cwdrmz
# 76017        https://devpost.com/software/saviour-cwdrmz
# 76081  https://devpost.com/software/validators-wars-f...
# 76082  https://devpost.com/software/validators-wars-f...
# 76104  https://devpost.com/software/azure-sentinel-as...
#
#                                             github_links start_date_format  \
# 5            https://github.com/Narwallets/meta-yield-ic        2022-05-10
# 8      https://github.com/NnsDao/nnsdao_sdk, https://...        2022-05-10
# 18     https://github.com/canscale/supernova-candb-de...        2022-05-10
# 21                      https://github.com/ZenVoich/mops        2022-05-10
# 42     https://github.com/hiukim/mind-ar-js, https://...        2022-05-10
# ...                                                  ...               ...
# 76016  https://github.com/Deblina28/Saviour, https://...        2021-07-16
# 76017  https://github.com/Deblina28/Saviour, https://...        2021-10-18
# 76081     https://github.com/selimerunkut/Validator_Wars        2021-11-11
# 76082     https://github.com/selimerunkut/Validator_Wars        2021-03-15
# 76104  https://github.com/hieuttmmo/Azure-Sentinel/tr...        2021-06-21
#
#       end_date_format                                       participants  \
# 5          2022-06-22  https://devpost.com/claudio744, https://devpos...
# 8          2022-06-22                     https://devpost.com/nnsdaos985
# 18         2022-06-22                   https://devpost.com/byron-becker
# 21         2022-06-22                       https://devpost.com/ZenVoich
# 42         2022-06-22  https://devpost.com/avirads, https://devpost.c...
# ...               ...                                                ...
# 76016      2021-07-18  https://devpost.com/avijitdasxp, https://devpo...
# 76017      2021-10-24  https://devpost.com/avijitdasxp, https://devpo...
# 76081      2021-12-10  https://devpost.com/alextazh, https://devpost....
# 76082      2021-03-28  https://devpost.com/alextazh, https://devpost....
# 76104      2021-10-04  https://devpost.com/duongkai, https://devpost....
#
#                                             contributors  \
# 5      https://github.com/imcsk8,https://github.com/j...
# 8      https://github.com/chuhemiao,https://github.co...
# 18     https://github.com/ByronBecker,https://github....
# 21     https://github.com/letmejustputthishere,https:...
# 42     https://github.com/Makio64,https://github.com/...
# ...                                                  ...
# 76016  https://github.com/Bodobolero,https://github.c...
# 76017  https://github.com/Bodobolero,https://github.c...
# 76081  https://github.com/adust09,https://github.com/...
# 76082  https://github.com/adust09,https://github.com/...
# 76104  https://github.com/9b,https://github.com/Amitb...
#
#                              contributor_github_username
# 5                          imcsk8,josemariasosa,leomanza
# 8                                    chuhemiao,rosendolu
# 18                                 ByronBecker,skilesare
# 21     letmejustputthishere,peterpeterparker,rvanasa,...
# 42     Makio64,jmswrnr,krpeacock,peterpeterparker,yos...
# ...                                                  ...
# 76016  Bodobolero,Dozingfiretruck,JohnZ03,LynnL4,MauA...
# 76017  Bodobolero,Dozingfiretruck,JohnZ03,LynnL4,MauA...
# 76081                               adust09,selimerunkut
# 76082                               adust09,selimerunkut
# 76104  9b,Amitbergman,Cyb3rWard0g,FlyingBlueMonkey,Ko...
#
# [2995 rows x 8 columns]

# %% [markdown]
# ##### 5.2 Keep Human and Unknown

# %%
proj_hack_member = pd.read_csv('../data/hackathon_project_contributor.csv')
humans_hash_complete = pd.read_csv('../data/humans_hash_complete.csv')

valid_links_complete = set(humans_hash_complete['link'])

# print(len(valid_links_complete))

# only keep links of human users
def filter_contributors(contributor_str):
    if pd.isna(contributor_str):
        return []
    links = [link.strip() for link in contributor_str.split(',')]
    filtered = [link for link in links if link in valid_links_complete]
    return filtered

proj_hack_member['contributors'] = proj_hack_member['contributors'].apply(filter_contributors)

# Only keep the projects with more than 1 human contributors
proj_hack_member = proj_hack_member[proj_hack_member['contributors'].apply(len) > 1]

# Transfer the contributor list back to string
proj_hack_member['contributors'] = proj_hack_member['contributors'].apply(lambda lst: ','.join(lst))

link_to_name = dict(zip(humans_hash_complete['link'], humans_hash_complete['name']))

def map_links_to_names(contributor_str):
    links = contributor_str.split(',')
    names = [link_to_name.get(link.strip()) for link in links if link.strip() in link_to_name]
    return ','.join(names)

proj_hack_member['contributor_github_username'] = proj_hack_member['contributors'].apply(map_links_to_names)

proj_hack_member.to_csv('../data/proj_hack_human_complete.csv',index=False)
proj_hack_member
# Out:
#                                            hackathon_URL  \
# 0                         https://supernova.devpost.com/
# 3                         https://supernova.devpost.com/
# 4                         https://supernova.devpost.com/
# 5                         https://supernova.devpost.com/
# 6                         https://supernova.devpost.com/
# ...                                                  ...
# 76255                 https://hacktech-2022.devpost.com/
# 76263               https://lhd-learn-day-3.devpost.com/
# 76264  https://chainlink-fall-hackathon-2021.devpost....
# 76265          https://topblockchainstartup.devpost.com/
# 76266                      https://ignition.devpost.com/
#
#                                              project_URL  \
# 0                   https://devpost.com/software/faefolk
# 3                   https://devpost.com/software/tingram
# 4               https://devpost.com/software/ant-kingdom
# 5      https://devpost.com/software/meta-yield-liquid...
# 6                 https://devpost.com/software/4everland
# ...                                                  ...
# 76255         https://devpost.com/software/suit-yourself
# 76263  https://devpost.com/software/track-your-learni...
# 76264        https://devpost.com/software/tsunami-fler8g
# 76265        https://devpost.com/software/tsunami-fler8g
# 76266        https://devpost.com/software/tsunami-fler8g
#
#                                             github_links start_date_format  \
# 0      https://github.com/ICCards/faefolk, https://gi...        2022-05-10
# 3              https://github.com/tingramtingram/dfinity        2022-05-10
# 4                    https://github.com/NFPTU/dfinity-fu        2022-05-10
# 5            https://github.com/Narwallets/meta-yield-ic        2022-05-10
# 6      https://github.com/4everland/dashboard-website...        2022-05-10
# ...                                                  ...               ...
# 76255  https://github.com/LilyPerr/hackscios, https:/...        2022-03-05
# 76263  https://github.com/ektaarora16/Track-your-Lear...        2021-10-12
# 76264  https://github.com/cryptohighway/fall-2021-tsu...        2021-10-22
# 76265  https://github.com/cryptohighway/fall-2021-tsu...        2021-06-15
# 76266  https://github.com/cryptohighway/fall-2021-tsu...        2021-08-31
#
#       end_date_format                                       participants  \
# 0          2022-06-22  https://devpost.com/RAW4RMCS, https://devpost....
# 3          2022-06-22  https://devpost.com/k-tsytsyn, https://devpost...
# 4          2022-06-22  https://devpost.com/damtuankhanglm1, https://d...
# 5          2022-06-22  https://devpost.com/claudio744, https://devpos...
# 6          2022-06-22                    https://devpost.com/4everlandoc
# ...               ...                                                ...
# 76255      2022-03-06  https://devpost.com/daneshbadlani, https://dev...
# 76263      2021-10-13  https://devpost.com/aaquib_dev, https://devpos...
# 76264      2021-11-29  https://devpost.com/Kryptokelli, https://devpo...
# 76265      2021-08-08  https://devpost.com/Kryptokelli, https://devpo...
# 76266      2021-10-16  https://devpost.com/Kryptokelli, https://devpo...
#
#                                             contributors  \
# 0      https://github.com/ALLiDoizCode,https://github...
# 3      https://github.com/stoma655,https://github.com...
# 4      https://github.com/DatTNT,https://github.com/a...
# 5      https://github.com/imcsk8,https://github.com/j...
# 6      https://github.com/haifun,https://github.com/h...
# ...                                                  ...
# 76255  https://github.com/huntleym,https://github.com...
# 76263  https://github.com/Ruthvik2127,https://github....
# 76264  https://github.com/PatrickAlphaC,https://githu...
# 76265  https://github.com/PatrickAlphaC,https://githu...
# 76266  https://github.com/PatrickAlphaC,https://githu...
#
#                              contributor_github_username
# 0                                  ALLiDoizCode,maxwisch
# 3                                stoma655,tingramtingram
# 4           DatTNT,anhth2912,khangdthe141099,thienvip107
# 5                          imcsk8,josemariasosa,leomanza
# 6      haifun,hyongnim,indirasieben,saullary,thloyi,y...
# ...                                                  ...
# 76255                              huntleym,kimiazargari
# 76263                Ruthvik2127,ektaarora16,imaaquibali
# 76264     PatrickAlphaC,cryptohighway,dwightjl,pappas999
# 76265     PatrickAlphaC,cryptohighway,dwightjl,pappas999
# 76266     PatrickAlphaC,cryptohighway,dwightjl,pappas999
#
# [36316 rows x 8 columns]
